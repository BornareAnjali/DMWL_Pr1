# %% [markdown]
# <a href="https://colab.research.google.com/github/BornareAnjali/DMWL_Pr1/blob/main/Data_Preprocessing_Rollno_86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Cleaning

# %%
#read .csv file
data = pd.read_csv('https://raw.githubusercontent.com/BornareAnjali/playstorecsv-file/main/googleplaystore.csv')

# %%
# isnull to find missing values
data.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
# to find sum of missing values
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#to check if file contains duplicate values
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Length: 10841, dtype: bool

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#normalize casing
data['Content Rating'] = data['Content Rating'].str.lower()

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#capitalize first character
data['Content Rating'] = data['Content Rating'].str.title()

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Data Integration

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import pandas as pd

# %%
#import csv file1
df=pd.read_csv('https://raw.githubusercontent.com/BornareAnjali/sample.csv/main/sample2.csv',error_bad_lines=False, engine="python")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Skipping line 1036: unexpected end of data

# %%
#import csv file2
df1=pd.read_csv('https://raw.githubusercontent.com/BornareAnjali/playstorecsv-file/main/googleplaystore.csv',error_bad_lines=False, engine="python")

# %%
#merge two csv files
output=pd.merge(df,df1,left_index=True,right_index=True)

# %%
#display first 15 rows of the merged csv file
output.head(15)
# Out:
#                Name  "Team"         "Position"   "Height(inches)"  \
# 0     Adam Donachie   "BAL"          "Catcher"                 74
# 1         Paul Bako   "BAL"          "Catcher"                 74
# 2   Ramon Hernandez   "BAL"          "Catcher"                 72
# 3      Kevin Millar   "BAL"    "First Baseman"                 72
# 4       Chris Gomez   "BAL"    "First Baseman"                 73
# 5     Brian Roberts   "BAL"   "Second Baseman"                 69
# 6     Miguel Tejada   "BAL"        "Shortstop"                 69
# 7       Melvin Mora   "BAL"    "Third Baseman"                 71
# 8       Aubrey Huff   "BAL"    "Third Baseman"                 76
# 9        Adam Stern   "BAL"       "Outfielder"                 71
# 10  Jeff Fiorentino   "BAL"       "Outfielder"                 73
# 11    Freddie Bynum   "BAL"       "Outfielder"                 73
# 12    Nick Markakis   "BAL"       "Outfielder"                 74
# ...

# %%
output
# Out:
#                  Name  "Team"         "Position"   "Height(inches)"  \
# 0       Adam Donachie   "BAL"          "Catcher"                 74
# 1           Paul Bako   "BAL"          "Catcher"                 74
# 2     Ramon Hernandez   "BAL"          "Catcher"                 72
# 3        Kevin Millar   "BAL"    "First Baseman"                 72
# 4         Chris Gomez   "BAL"    "First Baseman"                 73
# ...               ...     ...                ...                ...
# 1029    Brad Thompson   "STL"   "Relief Pitcher"                 73
# 1030    Tyler Johnson   "STL"   "Relief Pitcher"                 74
# 1031   Chris Narveson   "STL"   "Relief Pitcher"                 75
# 1032    Randy Keisler   "STL"   "Relief Pitcher"                 75
# 1033      Josh Kinney   "STL"   "Relief Pitcher"                 73
#
#       "Weight(lbs)"   "Age"  \
# 0               180   22.99
# 1               215   34.69
# 2               210   30.78
# 3               210   35.43
# ...

# %% [markdown]
# Data Reduction

# %%
#Data Reduction
set1=df1[['App','Category','Rating']]

# %%
set1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating
# 0         4.1
# ...

# %%
set2=df1[['App','Size','Type']]

# %%
#display set 2
display(set2)
# Out:
#                                                      App                Size  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 19M
# 1                                    Coloring book moana                 14M
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                8.7M
# 3                                  Sketch - Draw & Paint                 25M
# 4                  Pixel Draw - Number Art Coloring Book                2.8M
# ...                                                  ...                 ...
# 10836                                   Sya9a Maroc - FR                 53M
# 10837                   Fr. Mike Schmitz Audio Teachings                3.6M
# 10838                             Parkinson Exercices FR                9.5M
# 10839                      The SCP Foundation DB fr nn5n  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 19M
#
#        Type
# 0      Free
# 1      Free
# ...

# %%
set3=output[['Rating','Reviews','Price']]

# %%
set3
# Out:
#       Rating Reviews Price
# 0        4.1     159     0
# 1        3.9     967     0
# 2        4.7   87510     0
# 3        4.5  215644     0
# 4        4.3     967     0
# ...      ...     ...   ...
# 1029     4.4     663     0
# 1030     5.0      16     0
# 1031     4.5    1065     0
# 1032     NaN       3     0
# 1033     NaN      13     0
#
# [1034 rows x 3 columns]

# %% [markdown]
# Data Transformation

# %%
set3
# Out:
#       Rating Reviews Price
# 0        4.1     159     0
# 1        3.9     967     0
# 2        4.7   87510     0
# 3        4.5  215644     0
# 4        4.3     967     0
# ...      ...     ...   ...
# 1029     4.4     663     0
# 1030     5.0      16     0
# 1031     4.5    1065     0
# 1032     NaN       3     0
# 1033     NaN      13     0
#
# [1034 rows x 3 columns]

# %%
#display graph with help of hist()
set3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa370560c90>]],
#       dtype=object)
